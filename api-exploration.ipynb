# %%
import pandas as pd

import functions as func

# %%
api_url = 'https://gamesheetstats.com/api/useSeasonDivisions/getDivisions/6642'
df_div = func.parse_rest_api_to_pandas(api_url)
df_div
# Out:
#        id             title assistValue goalValue  playerStatsDisplay  \
# 0   37903  14U Girls Tier 2           1         1                True
# 1   37927        14U Tier 1           1         1                True
# 2   37905        10U Tier 2           1         1                True
# 3   37902        18U Tier 3           1         1                True
# 4   43064  10U Girls Tier 1           1         1                True
# 5   37926        15O Tier 1           1         1                True
# 6   37931        14U Tier 4           1         1                True
# 7   37914  12U Girls Tier 1           1         1                True
# 8   37909        14U Tier 2           1         1                True
# 9   37919        18U Tier 1           1         1                True
# 10  38324        12U Tier 1           1         1                True
# 11  37918  19U Girls Tier 2           1         1                True
# ...

# %%
api_url = 'https://gamesheetstats.com/api/useScoredGames/getSeasonScores/6642?filter[limit]=10000'

df_season = func.parse_rest_api_to_pandas(api_url)
df_season
# Out:
#                   date game.number       game.type game.time     game.date  \
# 0    Sat, Feb 15, 2025        None  Regular Season   7:47 PM  Feb 15, 2025
# 1    Sat, Feb 15, 2025     6950204  Regular Season   7:32 PM  Feb 15, 2025
# 2    Sat, Feb 15, 2025     6703687  Regular Season   5:58 PM  Feb 15, 2025
# 3    Sat, Feb 15, 2025     6749225  Regular Season   3:54 PM  Feb 15, 2025
# 4    Sat, Feb 15, 2025     6694611  Regular Season   3:18 PM  Feb 15, 2025
# ..                 ...         ...             ...       ...           ...
# 971   Sat, Sep 7, 2024     6674448  Regular Season   6:06 PM   Sep 7, 2024
# 972   Sat, Sep 7, 2024     6676288  Regular Season   5:30 PM   Sep 7, 2024
# 973   Sat, Sep 7, 2024     6676268  Regular Season   2:30 PM   Sep 7, 2024
# 974   Sat, Sep 7, 2024     6675036  Regular Season  12:20 PM   Sep 7, 2024
# 975   Sat, Sep 7, 2024     6672386  Regular Season  10:52 AM   Sep 7, 2024
#
# ...
